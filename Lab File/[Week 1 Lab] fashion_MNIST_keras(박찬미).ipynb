# %% [markdown]
# ### 실습 자료중 Minist with DNN이 비슷한 Flow이니까 참고해서 해주시면 됩니다.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import callbacks

from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ### 데이터 로드
# * TF에서 제공하는 데이터셋을 load해 간단한 전처리 진행

# %%
# Load training and eval data from tf.keras
(train_data, train_labels), (test_data, test_labels) = \
    tf.keras.datasets.fashion_mnist.load_data()

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
train_data, valid_data, train_labels, valid_labels = \
    train_test_split(train_data, train_labels, test_size=0.1, shuffle=True)

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (54000, 28, 28) (54000,)

# %%
print(valid_data.shape, valid_labels.shape)
# Out:
# (6000, 28, 28) (6000,)

# %%
index = 5901
print("label = {}".format(valid_labels[index]))
plt.imshow(valid_data[index].reshape(28, 28))
plt.colorbar()
#plt.gca().grid(False)
plt.show()
# Out:
# label = 4

# %%
train_data = train_data / 255.
train_data = train_data.reshape(-1, 28 * 28)
train_data = train_data.astype(np.float32)
train_labels = train_labels.astype(np.int32)

test_data = test_data / 255.
test_data = test_data.reshape(-1, 28 * 28)
test_data = test_data.astype(np.float32)
test_labels = test_labels.astype(np.int32)

valid_data = valid_data / 255.
valid_data = valid_data.reshape(-1, 28 * 28)
valid_data = valid_data.astype(np.float32)
valid_labels = valid_labels.astype(np.int32)


print(train_data.shape, train_labels.shape)
print(test_data.shape, test_labels.shape)
print(valid_data.shape, valid_labels.shape)
# Out:
# (54000, 784) (54000,)
# (10000, 784) (10000,)
# (6000, 784) (6000,)

# %% [markdown]
# ### 학습에 사용할 tf.data.Dataset 구성
# * 학습에 잘 적용할 수 있도록 label 처리
# * 데이터셋 구성
#
#
#
# ```
# # dataset format (dataloader 설정시)
# train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
# ```
#
#
#
# ```
# # 실행 결과
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# ```

# %%
def one_hot_label(image, label):
  label = tf.one_hot(label, depth=10)
  return image, label

# %%
batch_size = 32

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=10000)
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_labels))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)

# for test
valid_dataset = tf.data.Dataset.from_tensor_slices((valid_data, valid_labels))
valid_dataset = valid_dataset.map(one_hot_label)
valid_dataset = valid_dataset.batch(batch_size=batch_size)
print(valid_dataset)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# - Layer: input Layer: 64 -> 32 -> 16 -> output: 10 Layer

# %% [markdown]
# - tf.keras.layers.Dense format
# ```
#  def __init__(self,
#                units,
#                activation=None,
#                use_bias=True,
#                kernel_initializer='glorot_uniform',
#                bias_initializer='zeros',
#                kernel_regularizer=None,
#                bias_regularizer=None,
#                activity_regularizer=None,
#                kernel_constraint=None,
#                bias_constraint=None,
#                **kwargs):
# ```

# %%
# Flatten (inputs)
# Dense 64 relu
# Dense 32 relu
# Dense 16 relu
# (outputs)

model = tf.keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(10),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# without training, just inference a model in eager execution:
predictions = model(train_data[0:1], training=False)
print("Predictions: ", predictions.numpy())
# Out:
# Predictions:  [[-0.38899422  0.39335454 -0.17874645 -0.05382365 -0.07938311 -0.05200045
#    0.11781205 -0.28409854  0.21537705  0.04099895]]

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (1, 64)                   50240
#
#  dense_5 (Dense)             (1, 32)                   2080
#
#  dense_6 (Dense)             (1, 16)                   528
#
#  dense_7 (Dense)             (1, 10)                   170
#
# =================================================================
# Total params: 53018 (207.10 KB)
# Trainable params: 53018 (207.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 구성

# %%
check_point_cb = callbacks.ModelCheckpoint('fashion_mnist_model.h5',
                                           save_best_only=True,
                                           verbose=1)
early_stopping_cb = callbacks.EarlyStopping(patience=10,
                                            monitor='val_loss',
                                            restore_best_weights=True,
                                            verbose=1)

# %%
max_epochs = 100
# using `tf.data.Dataset`
history = model.fit(train_dataset,
                    epochs=max_epochs,
                    steps_per_epoch=len(train_data) // batch_size,
                    validation_data=valid_dataset,
                    validation_steps=len(valid_data) // batch_size,
                    callbacks=[check_point_cb, early_stopping_cb]
                   )
# Out:
# Epoch 1/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.8982 - accuracy: 0.7098
# Epoch 1: val_loss improved from inf to 0.55500, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.8965 - accuracy: 0.7104 - val_loss: 0.5550 - val_accuracy: 0.8160
# Epoch 2/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.5172 - accuracy: 0.8248
# Epoch 2: val_loss improved from 0.55500 to 0.46941, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.5173 - accuracy: 0.8247 - val_loss: 0.4694 - val_accuracy: 0.8399
# Epoch 3/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.4508 - accuracy: 0.8441
# Epoch 3: val_loss improved from 0.46941 to 0.43265, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.4507 - accuracy: 0.8443 - val_loss: 0.4327 - val_accuracy: 0.8501
# Epoch 4/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.4185 - accuracy: 0.8546
# Epoch 4: val_loss improved from 0.43265 to 0.41033, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.4184 - accuracy: 0.8546 - val_loss: 0.4103 - val_accuracy: 0.8570
# Epoch 5/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.3963 - accuracy: 0.8604
# Epoch 5: val_loss improved from 0.41033 to 0.39523, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3965 - accuracy: 0.8603 - val_loss: 0.3952 - val_accuracy: 0.8623
# Epoch 6/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.3813 - accuracy: 0.8647
# Epoch 6: val_loss improved from 0.39523 to 0.38433, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3811 - accuracy: 0.8648 - val_loss: 0.3843 - val_accuracy: 0.8628
# Epoch 7/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3686 - accuracy: 0.8700
# Epoch 7: val_loss improved from 0.38433 to 0.37189, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3688 - accuracy: 0.8699 - val_loss: 0.3719 - val_accuracy: 0.8700
# Epoch 8/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.3598 - accuracy: 0.8721
# Epoch 8: val_loss did not improve from 0.37189
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3596 - accuracy: 0.8722 - val_loss: 0.3763 - val_accuracy: 0.8673
# Epoch 9/100
# 1675/1687 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8759
# Epoch 9: val_loss improved from 0.37189 to 0.36301, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3507 - accuracy: 0.8759 - val_loss: 0.3630 - val_accuracy: 0.8745
# Epoch 10/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.3424 - accuracy: 0.8782
# Epoch 10: val_loss improved from 0.36301 to 0.35679, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3422 - accuracy: 0.8783 - val_loss: 0.3568 - val_accuracy: 0.8790
# Epoch 11/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.3359 - accuracy: 0.8808
# Epoch 11: val_loss improved from 0.35679 to 0.35439, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3362 - accuracy: 0.8807 - val_loss: 0.3544 - val_accuracy: 0.8770
# Epoch 12/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.3298 - accuracy: 0.8820
# Epoch 12: val_loss did not improve from 0.35439
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3298 - accuracy: 0.8820 - val_loss: 0.3575 - val_accuracy: 0.8772
# Epoch 13/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.3247 - accuracy: 0.8834
# Epoch 13: val_loss improved from 0.35439 to 0.34756, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.3246 - accuracy: 0.8834 - val_loss: 0.3476 - val_accuracy: 0.8770
# Epoch 14/100
# 1675/1687 [============================>.] - ETA: 0s - loss: 0.3197 - accuracy: 0.8851
# Epoch 14: val_loss did not improve from 0.34756
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3198 - accuracy: 0.8850 - val_loss: 0.3522 - val_accuracy: 0.8780
# Epoch 15/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3154 - accuracy: 0.8874
# Epoch 15: val_loss did not improve from 0.34756
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3152 - accuracy: 0.8874 - val_loss: 0.3479 - val_accuracy: 0.8777
# Epoch 16/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.3105 - accuracy: 0.8880
# Epoch 16: val_loss did not improve from 0.34756
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3106 - accuracy: 0.8879 - val_loss: 0.3514 - val_accuracy: 0.8790
# Epoch 17/100
# 1674/1687 [============================>.] - ETA: 0s - loss: 0.3061 - accuracy: 0.8912
# Epoch 17: val_loss did not improve from 0.34756
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3060 - accuracy: 0.8913 - val_loss: 0.3526 - val_accuracy: 0.8778
# Epoch 18/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.3021 - accuracy: 0.8914
# Epoch 18: val_loss improved from 0.34756 to 0.33814, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3024 - accuracy: 0.8913 - val_loss: 0.3381 - val_accuracy: 0.8815
# Epoch 19/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2989 - accuracy: 0.8917
# Epoch 19: val_loss did not improve from 0.33814
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2987 - accuracy: 0.8918 - val_loss: 0.3461 - val_accuracy: 0.8762
# Epoch 20/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2952 - accuracy: 0.8942
# Epoch 20: val_loss improved from 0.33814 to 0.33222, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2954 - accuracy: 0.8940 - val_loss: 0.3322 - val_accuracy: 0.8852
# Epoch 21/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2911 - accuracy: 0.8955
# Epoch 21: val_loss did not improve from 0.33222
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2910 - accuracy: 0.8955 - val_loss: 0.3459 - val_accuracy: 0.8788
# Epoch 22/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.2897 - accuracy: 0.8955
# Epoch 22: val_loss did not improve from 0.33222
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2898 - accuracy: 0.8953 - val_loss: 0.3329 - val_accuracy: 0.8850
# Epoch 23/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2854 - accuracy: 0.8976
# Epoch 23: val_loss improved from 0.33222 to 0.32748, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2855 - accuracy: 0.8975 - val_loss: 0.3275 - val_accuracy: 0.8875
# Epoch 24/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.8984
# Epoch 24: val_loss did not improve from 0.32748
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2816 - accuracy: 0.8986 - val_loss: 0.3280 - val_accuracy: 0.8857
# Epoch 25/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2790 - accuracy: 0.8999
# Epoch 25: val_loss did not improve from 0.32748
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2790 - accuracy: 0.8999 - val_loss: 0.3298 - val_accuracy: 0.8859
# Epoch 26/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2780 - accuracy: 0.8987
# Epoch 26: val_loss improved from 0.32748 to 0.32439, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2777 - accuracy: 0.8988 - val_loss: 0.3244 - val_accuracy: 0.8879
# Epoch 27/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2744 - accuracy: 0.8998
# Epoch 27: val_loss improved from 0.32439 to 0.32222, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2744 - accuracy: 0.8999 - val_loss: 0.3222 - val_accuracy: 0.8872
# Epoch 28/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2706 - accuracy: 0.9012
# Epoch 28: val_loss did not improve from 0.32222
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2706 - accuracy: 0.9013 - val_loss: 0.3255 - val_accuracy: 0.8874
# Epoch 29/100
# 1675/1687 [============================>.] - ETA: 0s - loss: 0.2684 - accuracy: 0.9030
# Epoch 29: val_loss did not improve from 0.32222
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2686 - accuracy: 0.9028 - val_loss: 0.3269 - val_accuracy: 0.8877
# Epoch 30/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2655 - accuracy: 0.9043
# Epoch 30: val_loss improved from 0.32222 to 0.32132, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2653 - accuracy: 0.9043 - val_loss: 0.3213 - val_accuracy: 0.8894
# Epoch 31/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2630 - accuracy: 0.9050
# Epoch 31: val_loss did not improve from 0.32132
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2630 - accuracy: 0.9050 - val_loss: 0.3340 - val_accuracy: 0.8850
# Epoch 32/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2607 - accuracy: 0.9054
# Epoch 32: val_loss did not improve from 0.32132
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2607 - accuracy: 0.9054 - val_loss: 0.3241 - val_accuracy: 0.8887
# Epoch 33/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.9068
# Epoch 33: val_loss improved from 0.32132 to 0.32087, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2580 - accuracy: 0.9068 - val_loss: 0.3209 - val_accuracy: 0.8909
# Epoch 34/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2555 - accuracy: 0.9071
# Epoch 34: val_loss did not improve from 0.32087
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2555 - accuracy: 0.9071 - val_loss: 0.3316 - val_accuracy: 0.8870
# Epoch 35/100
# 1675/1687 [============================>.] - ETA: 0s - loss: 0.2532 - accuracy: 0.9087
# Epoch 35: val_loss did not improve from 0.32087
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2531 - accuracy: 0.9087 - val_loss: 0.3235 - val_accuracy: 0.8895
# Epoch 36/100
# 1674/1687 [============================>.] - ETA: 0s - loss: 0.2515 - accuracy: 0.9096
# Epoch 36: val_loss improved from 0.32087 to 0.31947, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2514 - accuracy: 0.9096 - val_loss: 0.3195 - val_accuracy: 0.8904
# Epoch 37/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2502 - accuracy: 0.9097
# Epoch 37: val_loss did not improve from 0.31947
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2500 - accuracy: 0.9098 - val_loss: 0.3221 - val_accuracy: 0.8879
# Epoch 38/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2483 - accuracy: 0.9104
# Epoch 38: val_loss did not improve from 0.31947
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2482 - accuracy: 0.9104 - val_loss: 0.3207 - val_accuracy: 0.8890
# Epoch 39/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2450 - accuracy: 0.9107
# Epoch 39: val_loss did not improve from 0.31947
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2449 - accuracy: 0.9108 - val_loss: 0.3226 - val_accuracy: 0.8880
# Epoch 40/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2431 - accuracy: 0.9116
# Epoch 40: val_loss did not improve from 0.31947
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2431 - accuracy: 0.9116 - val_loss: 0.3203 - val_accuracy: 0.8889
# Epoch 41/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2414 - accuracy: 0.9125
# Epoch 41: val_loss did not improve from 0.31947
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2416 - accuracy: 0.9124 - val_loss: 0.3251 - val_accuracy: 0.8889
# Epoch 42/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2404 - accuracy: 0.9127
# Epoch 42: val_loss improved from 0.31947 to 0.31900, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2404 - accuracy: 0.9127 - val_loss: 0.3190 - val_accuracy: 0.8910
# Epoch 43/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9137
# Epoch 43: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2373 - accuracy: 0.9137 - val_loss: 0.3221 - val_accuracy: 0.8895
# Epoch 44/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.2368 - accuracy: 0.9124
# Epoch 44: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2369 - accuracy: 0.9124 - val_loss: 0.3493 - val_accuracy: 0.8844
# Epoch 45/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2334 - accuracy: 0.9152
# Epoch 45: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2334 - accuracy: 0.9152 - val_loss: 0.3242 - val_accuracy: 0.8897
# Epoch 46/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2325 - accuracy: 0.9153
# Epoch 46: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2324 - accuracy: 0.9152 - val_loss: 0.3207 - val_accuracy: 0.8927
# Epoch 47/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2297 - accuracy: 0.9168
# Epoch 47: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2299 - accuracy: 0.9166 - val_loss: 0.3203 - val_accuracy: 0.8925
# Epoch 48/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2280 - accuracy: 0.9172
# Epoch 48: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2282 - accuracy: 0.9172 - val_loss: 0.3308 - val_accuracy: 0.8895
# Epoch 49/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.2280 - accuracy: 0.9167
# Epoch 49: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2282 - accuracy: 0.9165 - val_loss: 0.3258 - val_accuracy: 0.8892
# Epoch 50/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.2249 - accuracy: 0.9182
# Epoch 50: val_loss did not improve from 0.31900
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2245 - accuracy: 0.9182 - val_loss: 0.3359 - val_accuracy: 0.8889
# Epoch 51/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2238 - accuracy: 0.9191
# Epoch 51: val_loss improved from 0.31900 to 0.31885, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2238 - accuracy: 0.9191 - val_loss: 0.3189 - val_accuracy: 0.8925
# Epoch 52/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2215 - accuracy: 0.9194
# Epoch 52: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2216 - accuracy: 0.9194 - val_loss: 0.3212 - val_accuracy: 0.8937
# Epoch 53/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2205 - accuracy: 0.9195
# Epoch 53: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2204 - accuracy: 0.9195 - val_loss: 0.3257 - val_accuracy: 0.8920
# Epoch 54/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.2194 - accuracy: 0.9200
# Epoch 54: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2193 - accuracy: 0.9201 - val_loss: 0.3274 - val_accuracy: 0.8887
# Epoch 55/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2161 - accuracy: 0.9219
# Epoch 55: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2161 - accuracy: 0.9219 - val_loss: 0.3401 - val_accuracy: 0.8832
# Epoch 56/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2159 - accuracy: 0.9201
# Epoch 56: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2160 - accuracy: 0.9201 - val_loss: 0.3217 - val_accuracy: 0.8929
# Epoch 57/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2131 - accuracy: 0.9230
# Epoch 57: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2130 - accuracy: 0.9230 - val_loss: 0.3300 - val_accuracy: 0.8909
# Epoch 58/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2119 - accuracy: 0.9235
# Epoch 58: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2119 - accuracy: 0.9235 - val_loss: 0.3227 - val_accuracy: 0.8924
# Epoch 59/100
# 1674/1687 [============================>.] - ETA: 0s - loss: 0.2099 - accuracy: 0.9243
# Epoch 59: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2100 - accuracy: 0.9242 - val_loss: 0.3308 - val_accuracy: 0.8885
# Epoch 60/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2105 - accuracy: 0.9238
# Epoch 60: val_loss did not improve from 0.31885
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2105 - accuracy: 0.9238 - val_loss: 0.3301 - val_accuracy: 0.8920
# Epoch 61/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.2063 - accuracy: 0.9247
# Epoch 61: val_loss did not improve from 0.31885
# Restoring model weights from the end of the best epoch: 51.
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2062 - accuracy: 0.9246 - val_loss: 0.3329 - val_accuracy: 0.8875
# Epoch 61: early stopping

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Valid Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Valid Loss')
plt.show()

# %%
results = model.evaluate(test_dataset)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3535 - accuracy: 0.8780
