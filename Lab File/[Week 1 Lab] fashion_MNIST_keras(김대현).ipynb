# %% [markdown]
# ### 실습 자료중 Minist with DNN이 비슷한 Flow이니까 참고해서 해주시면 됩니다.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import callbacks

from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ### 데이터 로드
# * TF에서 제공하는 데이터셋을 load해 간단한 전처리 진행

# %%
# Load training and eval data from tf.keras
(train_data, train_labels), (test_data, test_labels) = \
    tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
train_data, valid_data, train_labels, valid_labels = \
    train_test_split(train_data, train_labels, test_size=0.1, shuffle=True)

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (54000, 28, 28) (54000,)

# %%
print(valid_data.shape, valid_labels.shape)
# Out:
# (6000, 28, 28) (6000,)

# %%
index = 5901
print("label = {}".format(valid_labels[index]))
plt.imshow(valid_data[index].reshape(28, 28))
plt.colorbar()
#plt.gca().grid(False)
plt.show()
# Out:
# label = 6

# %%
train_data = train_data / 255.
train_data = train_data.reshape(-1, 28 * 28)
train_data = train_data.astype(np.float32)
train_labels = train_labels.astype(np.int32)

test_data = test_data / 255.
test_data = test_data.reshape(-1, 28 * 28)
test_data = test_data.astype(np.float32)
test_labels = test_labels.astype(np.int32)

valid_data = valid_data / 255.
valid_data = valid_data.reshape(-1, 28 * 28)
valid_data = valid_data.astype(np.float32)
valid_labels = valid_labels.astype(np.int32)


print(train_data.shape, train_labels.shape)
print(test_data.shape, test_labels.shape)
print(valid_data.shape, valid_labels.shape)
# Out:
# (54000, 784) (54000,)
# (10000, 784) (10000,)
# (6000, 784) (6000,)

# %% [markdown]
# ### 학습에 사용할 tf.data.Dataset 구성
# * 학습에 잘 적용할 수 있도록 label 처리
# * 데이터셋 구성
#
#
#
# ```
# # dataset format (dataloader 설정시)
# train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
# ```
#
#
#
# ```
# # 실행 결과
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# ```

# %%
def one_hot_label(image, label):
  label = tf.one_hot(label, depth=10)
  return image, label

# %%
batch_size = 32

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
train_dataset = train_dataset.shuffle(buffer_size=10000)
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_data, test_labels))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)

# for test
valid_dataset = tf.data.Dataset.from_tensor_slices((valid_data, valid_labels))
valid_dataset = valid_dataset.map(one_hot_label)
valid_dataset = valid_dataset.batch(batch_size=batch_size)
print(valid_dataset)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# - Layer: input Layer: 64 -> 32 -> 16 -> output: 10 Layer

# %% [markdown]
# - tf.keras.layers.Dense format
# ```
#  def __init__(self,
#                units,
#                activation=None,
#                use_bias=True,
#                kernel_initializer='glorot_uniform',
#                bias_initializer='zeros',
#                kernel_regularizer=None,
#                bias_regularizer=None,
#                activity_regularizer=None,
#                kernel_constraint=None,
#                bias_constraint=None,
#                **kwargs):
# ```

# %%
# Flatten (inputs)
# Dense 128 relu
# Dense 64 relu
# Dense 32 relu
# Dense 16 relu
# (outputs)

model = tf.keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(10),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# without training, just inference a model in eager execution:
predictions = model(train_data[0:1], training=False)
print("Predictions: ", predictions.numpy())
# Out:
# Predictions:  [[-0.07896432  0.00953897  0.02104543  0.15836816  0.07779871  0.5219538
#   -0.1142132   0.03122766  0.33335978 -0.16578546]]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (1, 64)                   50240
#
#  dense_1 (Dense)             (1, 32)                   2080
#
#  dense_2 (Dense)             (1, 16)                   528
#
#  dense_3 (Dense)             (1, 10)                   170
#
# =================================================================
# Total params: 53018 (207.10 KB)
# Trainable params: 53018 (207.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 구성

# %%
check_point_cb = callbacks.ModelCheckpoint('fashion_mnist_model.h5',
                                           save_best_only=True,
                                           verbose=1)
early_stopping_cb = callbacks.EarlyStopping(patience=10,
                                            monitor='val_loss',
                                            restore_best_weights=True,
                                            verbose=1)

# %%
max_epochs = 100
# using `tf.data.Dataset`
history = model.fit(train_dataset,
                    epochs=max_epochs,
                    steps_per_epoch=len(train_data) // batch_size,
                    validation_data=valid_dataset,
                    validation_steps=len(valid_data) // batch_size,
                    callbacks=[check_point_cb, early_stopping_cb]
                   )
# Out:
# Epoch 1/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.9146 - accuracy: 0.7126
# Epoch 1: val_loss improved from inf to 0.57010, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 10s 5ms/step - loss: 0.9135 - accuracy: 0.7129 - val_loss: 0.5701 - val_accuracy: 0.8150
# Epoch 2/100
#   29/1687 [..............................] - ETA: 6s - loss: 0.6352 - accuracy: 0.8103
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.5128 - accuracy: 0.8304
# Epoch 2: val_loss improved from 0.57010 to 0.47373, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.5127 - accuracy: 0.8304 - val_loss: 0.4737 - val_accuracy: 0.8431
# Epoch 3/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.4565 - accuracy: 0.8459
# Epoch 3: val_loss improved from 0.47373 to 0.44131, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.4564 - accuracy: 0.8459 - val_loss: 0.4413 - val_accuracy: 0.8575
# Epoch 4/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.4291 - accuracy: 0.8533
# Epoch 4: val_loss improved from 0.44131 to 0.41761, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.4292 - accuracy: 0.8532 - val_loss: 0.4176 - val_accuracy: 0.8603
# Epoch 5/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.4089 - accuracy: 0.8593
# Epoch 5: val_loss improved from 0.41761 to 0.40325, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.4089 - accuracy: 0.8593 - val_loss: 0.4033 - val_accuracy: 0.8668
# Epoch 6/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.3937 - accuracy: 0.8649
# Epoch 6: val_loss improved from 0.40325 to 0.40192, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3938 - accuracy: 0.8649 - val_loss: 0.4019 - val_accuracy: 0.8640
# Epoch 7/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.3818 - accuracy: 0.8670
# Epoch 7: val_loss improved from 0.40192 to 0.38812, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3818 - accuracy: 0.8669 - val_loss: 0.3881 - val_accuracy: 0.8683
# Epoch 8/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.3722 - accuracy: 0.8704
# Epoch 8: val_loss improved from 0.38812 to 0.37609, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3720 - accuracy: 0.8704 - val_loss: 0.3761 - val_accuracy: 0.8732
# Epoch 9/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3638 - accuracy: 0.8731
# Epoch 9: val_loss did not improve from 0.37609
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3641 - accuracy: 0.8729 - val_loss: 0.3795 - val_accuracy: 0.8718
# Epoch 10/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.3553 - accuracy: 0.8754
# Epoch 10: val_loss did not improve from 0.37609
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3550 - accuracy: 0.8755 - val_loss: 0.3774 - val_accuracy: 0.8713
# Epoch 11/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8781
# Epoch 11: val_loss improved from 0.37609 to 0.37193, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 10s 6ms/step - loss: 0.3494 - accuracy: 0.8782 - val_loss: 0.3719 - val_accuracy: 0.8725
# Epoch 12/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.3434 - accuracy: 0.8796
# Epoch 12: val_loss improved from 0.37193 to 0.36100, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3435 - accuracy: 0.8796 - val_loss: 0.3610 - val_accuracy: 0.8737
# Epoch 13/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.3364 - accuracy: 0.8827
# Epoch 13: val_loss improved from 0.36100 to 0.35117, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3364 - accuracy: 0.8827 - val_loss: 0.3512 - val_accuracy: 0.8802
# Epoch 14/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.3322 - accuracy: 0.8832
# Epoch 14: val_loss improved from 0.35117 to 0.34423, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3324 - accuracy: 0.8832 - val_loss: 0.3442 - val_accuracy: 0.8832
# Epoch 15/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.3266 - accuracy: 0.8854
# Epoch 15: val_loss improved from 0.34423 to 0.34000, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3265 - accuracy: 0.8854 - val_loss: 0.3400 - val_accuracy: 0.8830
# Epoch 16/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3231 - accuracy: 0.8855
# Epoch 16: val_loss did not improve from 0.34000
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3229 - accuracy: 0.8855 - val_loss: 0.3433 - val_accuracy: 0.8825
# Epoch 17/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.3174 - accuracy: 0.8886
# Epoch 17: val_loss did not improve from 0.34000
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3174 - accuracy: 0.8886 - val_loss: 0.3535 - val_accuracy: 0.8753
# Epoch 18/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3134 - accuracy: 0.8895
# Epoch 18: val_loss did not improve from 0.34000
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3136 - accuracy: 0.8895 - val_loss: 0.3491 - val_accuracy: 0.8770
# Epoch 19/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.8910
# Epoch 19: val_loss improved from 0.34000 to 0.33452, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3094 - accuracy: 0.8910 - val_loss: 0.3345 - val_accuracy: 0.8820
# Epoch 20/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3053 - accuracy: 0.8920
# Epoch 20: val_loss did not improve from 0.33452
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3057 - accuracy: 0.8918 - val_loss: 0.3403 - val_accuracy: 0.8793
# Epoch 21/100
# 1675/1687 [============================>.] - ETA: 0s - loss: 0.3027 - accuracy: 0.8935
# Epoch 21: val_loss improved from 0.33452 to 0.33086, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3026 - accuracy: 0.8934 - val_loss: 0.3309 - val_accuracy: 0.8817
# Epoch 22/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2980 - accuracy: 0.8947
# Epoch 22: val_loss did not improve from 0.33086
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2980 - accuracy: 0.8947 - val_loss: 0.3389 - val_accuracy: 0.8762
# Epoch 23/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2954 - accuracy: 0.8958
# Epoch 23: val_loss did not improve from 0.33086
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2954 - accuracy: 0.8958 - val_loss: 0.3373 - val_accuracy: 0.8795
# Epoch 24/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.2921 - accuracy: 0.8965
# Epoch 24: val_loss did not improve from 0.33086
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2921 - accuracy: 0.8964 - val_loss: 0.3456 - val_accuracy: 0.8797
# Epoch 25/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2882 - accuracy: 0.8983
# Epoch 25: val_loss improved from 0.33086 to 0.31822, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2881 - accuracy: 0.8982 - val_loss: 0.3182 - val_accuracy: 0.8872
# Epoch 26/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2850 - accuracy: 0.8978
# Epoch 26: val_loss did not improve from 0.31822
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2849 - accuracy: 0.8978 - val_loss: 0.3260 - val_accuracy: 0.8864
# Epoch 27/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.2828 - accuracy: 0.8996
# Epoch 27: val_loss did not improve from 0.31822
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2826 - accuracy: 0.8996 - val_loss: 0.3315 - val_accuracy: 0.8822
# Epoch 28/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.2799 - accuracy: 0.9001
# Epoch 28: val_loss did not improve from 0.31822
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2797 - accuracy: 0.9002 - val_loss: 0.3236 - val_accuracy: 0.8855
# Epoch 29/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2777 - accuracy: 0.9004
# Epoch 29: val_loss did not improve from 0.31822
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2773 - accuracy: 0.9005 - val_loss: 0.3447 - val_accuracy: 0.8819
# Epoch 30/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2746 - accuracy: 0.9028
# Epoch 30: val_loss did not improve from 0.31822
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2747 - accuracy: 0.9028 - val_loss: 0.3278 - val_accuracy: 0.8819
# Epoch 31/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2699 - accuracy: 0.9036
# Epoch 31: val_loss improved from 0.31822 to 0.31737, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2703 - accuracy: 0.9034 - val_loss: 0.3174 - val_accuracy: 0.8845
# Epoch 32/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2683 - accuracy: 0.9036
# Epoch 32: val_loss did not improve from 0.31737
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2683 - accuracy: 0.9036 - val_loss: 0.3224 - val_accuracy: 0.8862
# Epoch 33/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2666 - accuracy: 0.9041
# Epoch 33: val_loss did not improve from 0.31737
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2665 - accuracy: 0.9040 - val_loss: 0.3195 - val_accuracy: 0.8864
# Epoch 34/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2630 - accuracy: 0.9055
# Epoch 34: val_loss improved from 0.31737 to 0.31665, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2630 - accuracy: 0.9055 - val_loss: 0.3166 - val_accuracy: 0.8890
# Epoch 35/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2614 - accuracy: 0.9070
# Epoch 35: val_loss did not improve from 0.31665
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2614 - accuracy: 0.9070 - val_loss: 0.3203 - val_accuracy: 0.8882
# Epoch 36/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2595 - accuracy: 0.9070
# Epoch 36: val_loss improved from 0.31665 to 0.31355, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2594 - accuracy: 0.9071 - val_loss: 0.3136 - val_accuracy: 0.8887
# Epoch 37/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2568 - accuracy: 0.9086
# Epoch 37: val_loss did not improve from 0.31355
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2567 - accuracy: 0.9086 - val_loss: 0.3149 - val_accuracy: 0.8915
# Epoch 38/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.9081
# Epoch 38: val_loss did not improve from 0.31355
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2550 - accuracy: 0.9081 - val_loss: 0.3187 - val_accuracy: 0.8835
# Epoch 39/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2517 - accuracy: 0.9092
# Epoch 39: val_loss did not improve from 0.31355
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2516 - accuracy: 0.9093 - val_loss: 0.3193 - val_accuracy: 0.8884
# Epoch 40/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2504 - accuracy: 0.9099
# Epoch 40: val_loss did not improve from 0.31355
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2504 - accuracy: 0.9099 - val_loss: 0.3171 - val_accuracy: 0.8877
# Epoch 41/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.2489 - accuracy: 0.9101
# Epoch 41: val_loss improved from 0.31355 to 0.31019, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2488 - accuracy: 0.9101 - val_loss: 0.3102 - val_accuracy: 0.8924
# Epoch 42/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2456 - accuracy: 0.9122
# Epoch 42: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2458 - accuracy: 0.9122 - val_loss: 0.3140 - val_accuracy: 0.8892
# Epoch 43/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.2443 - accuracy: 0.9129
# Epoch 43: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2441 - accuracy: 0.9129 - val_loss: 0.3170 - val_accuracy: 0.8889
# Epoch 44/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2413 - accuracy: 0.9137
# Epoch 44: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2413 - accuracy: 0.9136 - val_loss: 0.3216 - val_accuracy: 0.8870
# Epoch 45/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9138
# Epoch 45: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2398 - accuracy: 0.9138 - val_loss: 0.3207 - val_accuracy: 0.8892
# Epoch 46/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2373 - accuracy: 0.9159
# Epoch 46: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2374 - accuracy: 0.9159 - val_loss: 0.3155 - val_accuracy: 0.8860
# Epoch 47/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2359 - accuracy: 0.9149
# Epoch 47: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2359 - accuracy: 0.9150 - val_loss: 0.3148 - val_accuracy: 0.8904
# Epoch 48/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.2353 - accuracy: 0.9160
# Epoch 48: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2353 - accuracy: 0.9160 - val_loss: 0.3130 - val_accuracy: 0.8909
# Epoch 49/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2329 - accuracy: 0.9157
# Epoch 49: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2327 - accuracy: 0.9158 - val_loss: 0.3118 - val_accuracy: 0.8894
# Epoch 50/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2300 - accuracy: 0.9179
# Epoch 50: val_loss did not improve from 0.31019
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2299 - accuracy: 0.9179 - val_loss: 0.3138 - val_accuracy: 0.8884
# Epoch 51/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2290 - accuracy: 0.9176
# Epoch 51: val_loss did not improve from 0.31019
# Restoring model weights from the end of the best epoch: 41.
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2289 - accuracy: 0.9177 - val_loss: 0.3141 - val_accuracy: 0.8909
# Epoch 51: early stopping

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Valid Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Valid Loss')
plt.show()

# %%
results = model.evaluate(test_dataset)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3529 - accuracy: 0.8753
