# %% [markdown]
# ### 실습 자료중 Minist with DNN이 비슷한 Flow이니까 참고해서 해주시면 됩니다.

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import callbacks

from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt

tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ### 데이터 로드
# * TF에서 제공하는 데이터셋을 load해 간단한 전처리 진행

# %%
# Load training and eval data from tf.keras
(train_data, train_labels), (test_data, test_labels) = \
    tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
train_data, valid_data, train_labels, valid_labels = \
    train_test_split(train_data, train_labels, test_size=0.1, shuffle=True)

# %%
print(train_data.shape, train_labels.shape)
# Out:
# (54000, 28, 28) (54000,)

# %%
print(valid_data.shape, valid_labels.shape)
# Out:
# (6000, 28, 28) (6000,)

# %%
index = 5901
print("label = {}".format(valid_labels[index]))
plt.imshow(valid_data[index].reshape(28, 28))
plt.colorbar()
#plt.gca().grid(False)
plt.show()
# Out:
# label = 2

# %%
train_data = train_data / 255.
train_data = train_data.reshape(-1, 28 * 28)
train_data = train_data.astype(np.float32)
train_labels = train_labels.astype(np.int32)

test_data = test_data / 255.
test_data = test_data.reshape(-1, 28 * 28)
test_data = test_data.astype(np.float32)
test_labels = test_labels.astype(np.int32)

valid_data = valid_data / 255.
valid_data = valid_data.reshape(-1, 28 * 28)
valid_data = valid_data.astype(np.float32)
valid_labels = valid_labels.astype(np.int32)


print(train_data.shape, train_labels.shape)
print(test_data.shape, test_labels.shape)
print(valid_data.shape, valid_labels.shape)
# Out:
# (54000, 784) (54000,)
# (10000, 784) (10000,)
# (6000, 784) (6000,)

# %% [markdown]
# ### 학습에 사용할 tf.data.Dataset 구성
# * 학습에 잘 적용할 수 있도록 label 처리
# * 데이터셋 구성
#
#
#
# ```
# # dataset format (dataloader 설정시)
# train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
# ```
#
#
#
# ```
# # 실행 결과
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# ```

# %%
def one_hot_label(image, label):
  label = tf.one_hot(label, depth=10)
  return image, label

# %%
batch_size = 32

# for train
train_dataset = tf.data.Dataset.from_tensor_slices((#, #))
train_dataset = train_dataset.shuffle(buffer_size=10000)
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=#)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((#, #))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=#)
print(test_dataset)

# for test
valid_dataset = tf.data.Dataset.from_tensor_slices((#, #))
valid_dataset = valid_dataset.map(one_hot_label)
valid_dataset = valid_dataset.batch(batch_size=#)
print(valid_dataset)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 784), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))>

# %% [markdown]
# ### 모델 구성

# %% [markdown]
# - Layer: input Layer: 64 -> 32 -> 16 -> output: 10 Layer

# %% [markdown]
# - tf.keras.layers.Dense format
# ```
#  def __init__(self,
#                units,
#                activation=None,
#                use_bias=True,
#                kernel_initializer='glorot_uniform',
#                bias_initializer='zeros',
#                kernel_regularizer=None,
#                bias_regularizer=None,
#                activity_regularizer=None,
#                kernel_constraint=None,
#                bias_constraint=None,
#                **kwargs):
# ```

# %%
# Flatten (inputs)
# Dense 128 relu
# Dense 64 relu
# Dense 32 relu
# Dense 16 relu
# (outputs)

model = tf.keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(10),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# without training, just inference a model in eager execution:
predictions = model(train_data[0:1], training=False)
print("Predictions: ", predictions.numpy())
# Out:
# Predictions:  [[-0.25213653 -0.2206885  -0.5097473  -0.35953066  0.25959113 -0.3579132
#    0.4796844   0.17233378 -0.16628765 -0.3528792 ]]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (1, 64)                   50240
#
#  dense_1 (Dense)             (1, 32)                   2080
#
#  dense_2 (Dense)             (1, 16)                   528
#
#  dense_3 (Dense)             (1, 10)                   170
#
# =================================================================
# Total params: 53018 (207.10 KB)
# Trainable params: 53018 (207.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 구성

# %%
check_point_cb = callbacks.ModelCheckpoint('fashion_mnist_model.h5',
                                           save_best_only=True,
                                           verbose=1)
early_stopping_cb = callbacks.EarlyStopping(patience=10,
                                            monitor='val_loss',
                                            restore_best_weights=True,
                                            verbose=1)

# %%
max_epochs = 100
# using `tf.data.Dataset`
history = model.fit(#,
                    epochs=max_epochs,
                    steps_per_epoch=len(#) // batch_size,
                    validation_data=valid_dataset,
                    validation_steps=len(#) // batch_size,
                    callbacks=[check_point_cb, early_stopping_cb]
                   )
# Out:
# Epoch 1/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 1.0025 - accuracy: 0.6813
# Epoch 1: val_loss improved from inf to 0.61087, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 18s 7ms/step - loss: 1.0000 - accuracy: 0.6820 - val_loss: 0.6109 - val_accuracy: 0.8058
# Epoch 2/100
#   40/1687 [..............................] - ETA: 6s - loss: 0.6191 - accuracy: 0.7930
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.5323 - accuracy: 0.8202
# Epoch 2: val_loss improved from 0.61087 to 0.48962, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 12s 7ms/step - loss: 0.5322 - accuracy: 0.8203 - val_loss: 0.4896 - val_accuracy: 0.8352
# Epoch 3/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.4619 - accuracy: 0.8409
# Epoch 3: val_loss improved from 0.48962 to 0.45449, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 10s 6ms/step - loss: 0.4619 - accuracy: 0.8410 - val_loss: 0.4545 - val_accuracy: 0.8438
# Epoch 4/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.4299 - accuracy: 0.8519
# Epoch 4: val_loss improved from 0.45449 to 0.42827, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.4298 - accuracy: 0.8519 - val_loss: 0.4283 - val_accuracy: 0.8563
# Epoch 5/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.4079 - accuracy: 0.8571
# Epoch 5: val_loss improved from 0.42827 to 0.42528, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.4080 - accuracy: 0.8572 - val_loss: 0.4253 - val_accuracy: 0.8544
# Epoch 6/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.3926 - accuracy: 0.8627
# Epoch 6: val_loss improved from 0.42528 to 0.40327, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3928 - accuracy: 0.8627 - val_loss: 0.4033 - val_accuracy: 0.8616
# Epoch 7/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.3805 - accuracy: 0.8657
# Epoch 7: val_loss improved from 0.40327 to 0.39193, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3803 - accuracy: 0.8658 - val_loss: 0.3919 - val_accuracy: 0.8640
# Epoch 8/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.3693 - accuracy: 0.8699
# Epoch 8: val_loss improved from 0.39193 to 0.38500, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3693 - accuracy: 0.8699 - val_loss: 0.3850 - val_accuracy: 0.8670
# Epoch 9/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.3611 - accuracy: 0.8722
# Epoch 9: val_loss improved from 0.38500 to 0.37733, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3608 - accuracy: 0.8722 - val_loss: 0.3773 - val_accuracy: 0.8708
# Epoch 10/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.3528 - accuracy: 0.8755
# Epoch 10: val_loss did not improve from 0.37733
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3529 - accuracy: 0.8753 - val_loss: 0.3951 - val_accuracy: 0.8635
# Epoch 11/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.3442 - accuracy: 0.8782
# Epoch 11: val_loss improved from 0.37733 to 0.37186, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3446 - accuracy: 0.8781 - val_loss: 0.3719 - val_accuracy: 0.8738
# Epoch 12/100
# 1677/1687 [============================>.] - ETA: 0s - loss: 0.3393 - accuracy: 0.8782
# Epoch 12: val_loss did not improve from 0.37186
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3394 - accuracy: 0.8782 - val_loss: 0.3743 - val_accuracy: 0.8727
# Epoch 13/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.3337 - accuracy: 0.8800
# Epoch 13: val_loss improved from 0.37186 to 0.35997, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 9s 5ms/step - loss: 0.3339 - accuracy: 0.8799 - val_loss: 0.3600 - val_accuracy: 0.8785
# Epoch 14/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.3274 - accuracy: 0.8827
# Epoch 14: val_loss did not improve from 0.35997
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3275 - accuracy: 0.8828 - val_loss: 0.3629 - val_accuracy: 0.8780
# Epoch 15/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.3227 - accuracy: 0.8839
# Epoch 15: val_loss improved from 0.35997 to 0.35906, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3224 - accuracy: 0.8840 - val_loss: 0.3591 - val_accuracy: 0.8787
# Epoch 16/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3178 - accuracy: 0.8876
# Epoch 16: val_loss improved from 0.35906 to 0.35623, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3179 - accuracy: 0.8876 - val_loss: 0.3562 - val_accuracy: 0.8815
# Epoch 17/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3131 - accuracy: 0.8881
# Epoch 17: val_loss improved from 0.35623 to 0.35447, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3132 - accuracy: 0.8880 - val_loss: 0.3545 - val_accuracy: 0.8773
# Epoch 18/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.3098 - accuracy: 0.8888
# Epoch 18: val_loss improved from 0.35447 to 0.35208, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3097 - accuracy: 0.8888 - val_loss: 0.3521 - val_accuracy: 0.8792
# Epoch 19/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.3047 - accuracy: 0.8915
# Epoch 19: val_loss improved from 0.35208 to 0.34988, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.3046 - accuracy: 0.8916 - val_loss: 0.3499 - val_accuracy: 0.8814
# Epoch 20/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.3020 - accuracy: 0.8917
# Epoch 20: val_loss improved from 0.34988 to 0.34477, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.3021 - accuracy: 0.8917 - val_loss: 0.3448 - val_accuracy: 0.8835
# Epoch 21/100
# 1674/1687 [============================>.] - ETA: 0s - loss: 0.2985 - accuracy: 0.8922
# Epoch 21: val_loss did not improve from 0.34477
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2979 - accuracy: 0.8925 - val_loss: 0.3496 - val_accuracy: 0.8770
# Epoch 22/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.2938 - accuracy: 0.8938
# Epoch 22: val_loss improved from 0.34477 to 0.33616, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2939 - accuracy: 0.8938 - val_loss: 0.3362 - val_accuracy: 0.8877
# Epoch 23/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2912 - accuracy: 0.8947
# Epoch 23: val_loss did not improve from 0.33616
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2910 - accuracy: 0.8947 - val_loss: 0.3516 - val_accuracy: 0.8788
# Epoch 24/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2874 - accuracy: 0.8964
# Epoch 24: val_loss did not improve from 0.33616
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2873 - accuracy: 0.8964 - val_loss: 0.3419 - val_accuracy: 0.8822
# Epoch 25/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2839 - accuracy: 0.8976
# Epoch 25: val_loss did not improve from 0.33616
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2841 - accuracy: 0.8975 - val_loss: 0.3374 - val_accuracy: 0.8840
# Epoch 26/100
# 1681/1687 [============================>.] - ETA: 0s - loss: 0.2820 - accuracy: 0.8982
# Epoch 26: val_loss improved from 0.33616 to 0.33545, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2823 - accuracy: 0.8981 - val_loss: 0.3354 - val_accuracy: 0.8840
# Epoch 27/100
# 1676/1687 [============================>.] - ETA: 0s - loss: 0.2781 - accuracy: 0.8999
# Epoch 27: val_loss improved from 0.33545 to 0.33502, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2783 - accuracy: 0.8998 - val_loss: 0.3350 - val_accuracy: 0.8852
# Epoch 28/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2755 - accuracy: 0.9010
# Epoch 28: val_loss did not improve from 0.33502
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2756 - accuracy: 0.9010 - val_loss: 0.3357 - val_accuracy: 0.8842
# Epoch 29/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2723 - accuracy: 0.9009
# Epoch 29: val_loss did not improve from 0.33502
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2725 - accuracy: 0.9009 - val_loss: 0.3517 - val_accuracy: 0.8762
# Epoch 30/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2696 - accuracy: 0.9021
# Epoch 30: val_loss did not improve from 0.33502
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2695 - accuracy: 0.9021 - val_loss: 0.3500 - val_accuracy: 0.8803
# Epoch 31/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2686 - accuracy: 0.9027
# Epoch 31: val_loss improved from 0.33502 to 0.33500, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2685 - accuracy: 0.9027 - val_loss: 0.3350 - val_accuracy: 0.8850
# Epoch 32/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2639 - accuracy: 0.9047
# Epoch 32: val_loss did not improve from 0.33500
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2640 - accuracy: 0.9046 - val_loss: 0.3351 - val_accuracy: 0.8867
# Epoch 33/100
# 1683/1687 [============================>.] - ETA: 0s - loss: 0.2620 - accuracy: 0.9055
# Epoch 33: val_loss improved from 0.33500 to 0.33210, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 9s 5ms/step - loss: 0.2619 - accuracy: 0.9055 - val_loss: 0.3321 - val_accuracy: 0.8885
# Epoch 34/100
# 1687/1687 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.9055
# Epoch 34: val_loss improved from 0.33210 to 0.33122, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2601 - accuracy: 0.9055 - val_loss: 0.3312 - val_accuracy: 0.8839
# Epoch 35/100
# 1674/1687 [============================>.] - ETA: 0s - loss: 0.2569 - accuracy: 0.9065
# Epoch 35: val_loss did not improve from 0.33122
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2569 - accuracy: 0.9065 - val_loss: 0.3320 - val_accuracy: 0.8865
# Epoch 36/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2548 - accuracy: 0.9075
# Epoch 36: val_loss improved from 0.33122 to 0.32588, saving model to fashion_mnist_model.h5
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2549 - accuracy: 0.9075 - val_loss: 0.3259 - val_accuracy: 0.8870
# Epoch 37/100
# 1679/1687 [============================>.] - ETA: 0s - loss: 0.2531 - accuracy: 0.9081
# Epoch 37: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2528 - accuracy: 0.9082 - val_loss: 0.3367 - val_accuracy: 0.8834
# Epoch 38/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2496 - accuracy: 0.9099
# Epoch 38: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2497 - accuracy: 0.9099 - val_loss: 0.3400 - val_accuracy: 0.8825
# Epoch 39/100
# 1682/1687 [============================>.] - ETA: 0s - loss: 0.2485 - accuracy: 0.9102
# Epoch 39: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2484 - accuracy: 0.9102 - val_loss: 0.3286 - val_accuracy: 0.8852
# Epoch 40/100
# 1684/1687 [============================>.] - ETA: 0s - loss: 0.2456 - accuracy: 0.9110
# Epoch 40: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2455 - accuracy: 0.9111 - val_loss: 0.3311 - val_accuracy: 0.8854
# Epoch 41/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2445 - accuracy: 0.9119
# Epoch 41: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2447 - accuracy: 0.9119 - val_loss: 0.3280 - val_accuracy: 0.8875
# Epoch 42/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2418 - accuracy: 0.9124
# Epoch 42: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2421 - accuracy: 0.9123 - val_loss: 0.3260 - val_accuracy: 0.8909
# Epoch 43/100
# 1685/1687 [============================>.] - ETA: 0s - loss: 0.2385 - accuracy: 0.9140
# Epoch 43: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2384 - accuracy: 0.9140 - val_loss: 0.3602 - val_accuracy: 0.8788
# Epoch 44/100
# 1680/1687 [============================>.] - ETA: 0s - loss: 0.2370 - accuracy: 0.9133
# Epoch 44: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 4ms/step - loss: 0.2372 - accuracy: 0.9133 - val_loss: 0.3360 - val_accuracy: 0.8840
# Epoch 45/100
# 1686/1687 [============================>.] - ETA: 0s - loss: 0.2351 - accuracy: 0.9151
# Epoch 45: val_loss did not improve from 0.32588
# 1687/1687 [==============================] - 8s 5ms/step - loss: 0.2351 - accuracy: 0.9152 - val_loss: 0.3408 - val_accuracy: 0.8862
# Epoch 46/100
# 1678/1687 [============================>.] - ETA: 0s - loss: 0.2328 - accuracy: 0.9148
# Epoch 46: val_loss did not improve from 0.32588
# Restoring model weights from the end of the best epoch: 36.
# 1687/1687 [==============================] - 7s 4ms/step - loss: 0.2328 - accuracy: 0.9148 - val_loss: 0.3326 - val_accuracy: 0.8854
# Epoch 46: early stopping

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Valid Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Valid Loss')
plt.show()

# %%
results = model.evaluate(test_dataset)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3580 - accuracy: 0.8738
